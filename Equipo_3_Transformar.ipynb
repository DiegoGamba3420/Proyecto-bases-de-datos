# %% [markdown]
# ## TRANSFORMACION FUENTES RECOMENDADAS CASO DE ESTUDIO##

# %% [markdown]
# > ## 1.SET DE DATOS DE LA ENCUESTA DE POBREZA INDIGENA EN GUATEMALA:
#
#
# https://docs.google.com/spreadsheets/d/1W2alp2D_7WGROHZBiCBLeuo3v67uHE9x/edit?usp=sharing&ouid=102053652424287329875&rtpof=true&sd=true

# %% [markdown]
# 1. Eliminar datos en blanco
# 2. Eliminar duplicados
# 3. Eliminar variable rural
# 4. Validación de la edad
# 5. Cambiar codificación de estado civil
# 6. Arreglar errores con expresiones regulares

# %% [markdown]
# ##**<font color='#BF4AD4'>Cargue de librerias</font>**

# %%
import pandas as pd
from datetime import datetime
from dateutil.relativedelta import relativedelta
from google.colab import files
from datetime import datetime, timedelta
import openpyxl

# %% [markdown]
# ## **<font color='#3498DB'>Cargue del dataframe</font>**

# %%
url = "https://raw.githubusercontent.com/Omaira85/BASES-DE-DATOS-SEG-SEMESTRE/main/Poverty%20test%20file%20-%20Guatemala_BM_V1.csv"
proverty = pd.read_csv(url, sep=';')
proverty.head()
# Out:
#   nombre_departamento nombre_municipio  nombre_lugar_poblado tipo_area  \
# 0          SAN MARCOS        SAN PABLO        BARRANCA HONDA     RURAL
# 1          SAN MARCOS     COMITANCILLO              CHAMAQUE     RURAL
# 2          SAN MARCOS      SAN LORENZO  SANTA ROSA (CASERIO)     RURAL
# 3          SAN MARCOS     COMITANCILLO              CHAMAQUE     RURAL
# 4          SAN MARCOS        SAN PABLO             LA CUMBRE     RURAL
#
#    cod_familia fecha_nacimiento  edad    sexo  nucleo   estado_conyugal  \
# 0  609497670.0  27/11/1962 0:00  57.0   Mujer     1.0            Casado
# 1    8600484.0   2/05/2003 0:00  17.0   Mujer     1.0        Soltero(a)
# 2   13648135.0  30/07/1977 0:00  43.0   Mujer     1.0            Casado
# 3    8600465.0  26/04/2004 0:00  16.0   Mujer     1.0  Menos de 12 años
# 4  609499178.0  29/04/2006 0:00  14.0  Hombre     1.0  Menos de 12 años
#
#   discapacidad_permanente sabe_leer_escribir asistencia_centro_educativo  \
# 0                     NaN                 No                          No
# 1                     NaN                 Sí                          Sí
# 2                     NaN                 Sí                          No
# 3                     NaN                 Sí                          Sí
# 4                     NaN                 Sí                          Sí
#
#   razon_dejo_asistir   nivel_inscrito    nivel_aprobado  \
# 0     No le interesa          Ninguno           Ninguno
# 1                NaN   Sexto Primaria   Quinto Primaria
# 2    Falta de dinero          Ninguno  Primero Primaria
# 3                NaN  Cuarto Primaria  Tercero Primaria
# 4                NaN  Quinto Primaria   Cuarto Primaria
#
#                   categoria_ocupacional grupo_etnico es_jefe_familia
# 0  Trabajador(a) cuenta propia agrícola  No indigena              Sí
# 1                                   NaN          Mam              No
# 2                            No Trabaja          Mam              No
# 3                                   NaN          Mam              No
# 4                                   NaN  No indigena              No

# %% [markdown]
# ## **<font color='#2ECC71'>Analisis del Dataframe</font>**

# %% [markdown]
# ### **Nombre de las columnas del dataframe df1**

# %%
proverty.columns
# Out:
# Index(['nombre_departamento', 'nombre_municipio', 'nombre_lugar_poblado',
#        'tipo_area', 'cod_familia', 'fecha_nacimiento', 'edad', 'sexo',
#        'nucleo', 'estado_conyugal', 'discapacidad_permanente',
#        'sabe_leer_escribir', 'asistencia_centro_educativo',
#        'razon_dejo_asistir', 'nivel_inscrito', 'nivel_aprobado',
#        'categoria_ocupacional', 'grupo_etnico', 'es_jefe_familia'],
#       dtype='object')

# %% [markdown]
# ### **Informacion de la base y tipos de variables de cada una de las columnas del Dataframe**

# %%
proverty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12073 entries, 0 to 12072
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   nombre_departamento          12024 non-null  object
#  1   nombre_municipio             12024 non-null  object
#  2   nombre_lugar_poblado         12037 non-null  object
#  3   tipo_area                    12037 non-null  object
#  4   cod_familia                  11988 non-null  float64
#  5   fecha_nacimiento             11988 non-null  object
#  6   edad                         11988 non-null  float64
#  7   sexo                         11988 non-null  object
#  8   nucleo                       11988 non-null  float64
#  9   estado_conyugal              11988 non-null  object
#  10  discapacidad_permanente      24 non-null     object
#  11  sabe_leer_escribir           10008 non-null  object
#  12  asistencia_centro_educativo  10008 non-null  object
#  13  razon_dejo_asistir           4092 non-null   object
#  14  nivel_inscrito               11988 non-null  object
#  15  nivel_aprobado               11988 non-null  object
#  16  categoria_ocupacional        3156 non-null   object
#  17  grupo_etnico                 11988 non-null  object
#  18  es_jefe_familia              11988 non-null  object
# dtypes: float64(3), object(16)
# memory usage: 1.8+ MB

# %% [markdown]
# ## **Dimensiones del Dataframe y limpieza**

# %% [markdown]
# ##**tamaño**

# %%
print(proverty.shape)
# Out:
# (12073, 19)

# %% [markdown]
# ### **Suma la cantidad de nulos por cada columna del Dataframe**

# %%
print(proverty.shape) 
print(proverty.shape[0]) 
print(proverty.shape[1]) 
celdas0=proverty.shape[0]*proverty.shape[1]
print(celdas0)
# Out:
# (12073, 19)
# 12073
# 19
# 229387

# %%
nulos=proverty.isnull().sum().sum()
nulos
# Out:
# 34097

# %%
cociente=nulos/celdas0
print("Fracción de datos faltantes: ","{:.2}".format(cociente))
print("Porcentaje de datos faltantes: ","{:.2%}".format(cociente))
# Out:
# Fracción de datos faltantes:  0.15
# Porcentaje de datos faltantes:  14.86%

# %% [markdown]
# ### **Elimina los registros duplicados del Dataframe**

# %%
df = proverty.drop_duplicates()
df
# Out:
#      nombre_departamento             nombre_municipio  nombre_lugar_poblado  \
# 0             SAN MARCOS                    SAN PABLO        BARRANCA HONDA
# 1             SAN MARCOS                 COMITANCILLO              CHAMAQUE
# 2             SAN MARCOS                  SAN LORENZO  SANTA ROSA (CASERIO)
# 3             SAN MARCOS                 COMITANCILLO              CHAMAQUE
# 4             SAN MARCOS                    SAN PABLO             LA CUMBRE
# ...                  ...                          ...                   ...
# 4280       HUEHUETENANGO              SAN JUAN ATITÁN              IXQUILAM
# 4375              SOLOLA           SAN JUAN LA LAGUNA             PASAJQUIM
# 4854       HUEHUETENANGO  SAN SEBASTIÁN HUEHUETENANGO                 SUJAL
# 6267          SAN MARCOS                       AYUTLA                   NaN
# 8924          SAN MARCOS                    SAN PABLO                   NaN
#
#      tipo_area  cod_familia fecha_nacimiento  edad    sexo  nucleo  \
# 0        RURAL  609497670.0  27/11/1962 0:00  57.0   Mujer     1.0
# 1        RURAL    8600484.0   2/05/2003 0:00  17.0   Mujer     1.0
# 2        RURAL   13648135.0  30/07/1977 0:00  43.0   Mujer     1.0
# 3        RURAL    8600465.0  26/04/2004 0:00  16.0   Mujer     1.0
# 4        RURAL  609499178.0  29/04/2006 0:00  14.0  Hombre     1.0
# ...        ...          ...              ...   ...     ...     ...
# 4280     RURAL  657997897.0  28/08/2006 0:00  14.0  Hombre     1.0
# 4375     RURAL  358497825.0   5/02/2009 0:00  11.0  Hombre     1.0
# 4854     RURAL    9748739.0  23/10/2008 0:00  11.0   Mujer     1.0
# 6267       NaN          NaN              NaN   NaN     NaN     NaN
# 8924       NaN          NaN              NaN   NaN     NaN     NaN
#
#        estado_conyugal discapacidad_permanente sabe_leer_escribir  \
# 0               Casado                     NaN                 No
# 1           Soltero(a)                     NaN                 Sí
# 2               Casado                     NaN                 Sí
# 3     Menos de 12 años                     NaN                 Sí
# 4     Menos de 12 años                     NaN                 Sí
# ...                ...                     ...                ...
# 4280  Menos de 12 años                     NaN                 Sí
# 4375  Menos de 12 años                     NaN                 Sí
# 4854  Menos de 12 años                     NaN                 Sí
# 6267               NaN                     NaN                NaN
# 8924               NaN                     NaN                NaN
#
#      asistencia_centro_educativo razon_dejo_asistir    nivel_inscrito  \
# 0                             No     No le interesa           Ninguno
# 1                             Sí                NaN    Sexto Primaria
# 2                             No    Falta de dinero           Ninguno
# 3                             Sí                NaN   Cuarto Primaria
# 4                             Sí                NaN   Quinto Primaria
# ...                          ...                ...               ...
# 4280                          Sí                NaN  Segundo Primaria
# 4375                          Sí                NaN  Primero Primaria
# 4854                          Sí                NaN  Segundo Primaria
# 6267                         NaN                NaN               NaN
# 8924                         NaN                NaN               NaN
#
#         nivel_aprobado                 categoria_ocupacional grupo_etnico  \
# 0              Ninguno  Trabajador(a) cuenta propia agrícola  No indigena
# 1      Quinto Primaria                                   NaN          Mam
# 2     Primero Primaria                            No Trabaja          Mam
# 3     Tercero Primaria                                   NaN          Mam
# 4      Cuarto Primaria                                   NaN  No indigena
# ...                ...                                   ...          ...
# 4280  Primero Primaria                                   NaN          Mam
# 4375       Preprimaria                                   NaN        Kiche
# 4854  Primero Primaria                                   NaN          Mam
# 6267               NaN                                   NaN          NaN
# 8924               NaN                                   NaN          NaN
#
#      es_jefe_familia
# 0                 Sí
# 1                 No
# 2                 No
# 3                 No
# 4                 No
# ...              ...
# 4280              No
# 4375              No
# 4854              No
# 6267             NaN
# 8924             NaN
#
# [1010 rows x 19 columns]

# %% [markdown]
# ### **La columna tipo_area muestra un único valor o datos faltantes, por lo tanto no aporta información. Se elimina**

# %%
df.drop(['tipo_area'], axis = 'columns', inplace=True)
df
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#      nombre_departamento             nombre_municipio  nombre_lugar_poblado  \
# 0             SAN MARCOS                    SAN PABLO        BARRANCA HONDA
# 1             SAN MARCOS                 COMITANCILLO              CHAMAQUE
# 2             SAN MARCOS                  SAN LORENZO  SANTA ROSA (CASERIO)
# 3             SAN MARCOS                 COMITANCILLO              CHAMAQUE
# 4             SAN MARCOS                    SAN PABLO             LA CUMBRE
# ...                  ...                          ...                   ...
# 4280       HUEHUETENANGO              SAN JUAN ATITÁN              IXQUILAM
# 4375              SOLOLA           SAN JUAN LA LAGUNA             PASAJQUIM
# 4854       HUEHUETENANGO  SAN SEBASTIÁN HUEHUETENANGO                 SUJAL
# 6267          SAN MARCOS                       AYUTLA                   NaN
# 8924          SAN MARCOS                    SAN PABLO                   NaN
#
#       cod_familia fecha_nacimiento  edad    sexo  nucleo   estado_conyugal  \
# 0     609497670.0  27/11/1962 0:00  57.0   Mujer     1.0            Casado
# 1       8600484.0   2/05/2003 0:00  17.0   Mujer     1.0        Soltero(a)
# 2      13648135.0  30/07/1977 0:00  43.0   Mujer     1.0            Casado
# 3       8600465.0  26/04/2004 0:00  16.0   Mujer     1.0  Menos de 12 años
# 4     609499178.0  29/04/2006 0:00  14.0  Hombre     1.0  Menos de 12 años
# ...           ...              ...   ...     ...     ...               ...
# 4280  657997897.0  28/08/2006 0:00  14.0  Hombre     1.0  Menos de 12 años
# 4375  358497825.0   5/02/2009 0:00  11.0  Hombre     1.0  Menos de 12 años
# 4854    9748739.0  23/10/2008 0:00  11.0   Mujer     1.0  Menos de 12 años
# 6267          NaN              NaN   NaN     NaN     NaN               NaN
# 8924          NaN              NaN   NaN     NaN     NaN               NaN
#
#      discapacidad_permanente sabe_leer_escribir asistencia_centro_educativo  \
# 0                        NaN                 No                          No
# 1                        NaN                 Sí                          Sí
# 2                        NaN                 Sí                          No
# 3                        NaN                 Sí                          Sí
# 4                        NaN                 Sí                          Sí
# ...                      ...                ...                         ...
# 4280                     NaN                 Sí                          Sí
# 4375                     NaN                 Sí                          Sí
# 4854                     NaN                 Sí                          Sí
# 6267                     NaN                NaN                         NaN
# 8924                     NaN                NaN                         NaN
#
#      razon_dejo_asistir    nivel_inscrito    nivel_aprobado  \
# 0        No le interesa           Ninguno           Ninguno
# 1                   NaN    Sexto Primaria   Quinto Primaria
# 2       Falta de dinero           Ninguno  Primero Primaria
# 3                   NaN   Cuarto Primaria  Tercero Primaria
# 4                   NaN   Quinto Primaria   Cuarto Primaria
# ...                 ...               ...               ...
# 4280                NaN  Segundo Primaria  Primero Primaria
# 4375                NaN  Primero Primaria       Preprimaria
# 4854                NaN  Segundo Primaria  Primero Primaria
# 6267                NaN               NaN               NaN
# 8924                NaN               NaN               NaN
#
#                      categoria_ocupacional grupo_etnico es_jefe_familia
# 0     Trabajador(a) cuenta propia agrícola  No indigena              Sí
# 1                                      NaN          Mam              No
# 2                               No Trabaja          Mam              No
# 3                                      NaN          Mam              No
# 4                                      NaN  No indigena              No
# ...                                    ...          ...             ...
# 4280                                   NaN          Mam              No
# 4375                                   NaN        Kiche              No
# 4854                                   NaN          Mam              No
# 6267                                   NaN          NaN             NaN
# 8924                                   NaN          NaN             NaN
#
# [1010 rows x 18 columns]

# %%
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### **Se elimina las filas que presentan mayor cantidad de datos nulos**

# %%
a = df.isnull().sum(axis=1)
print (a[a>15])
# Out:
# 179     17
# 187     17
# 429     17
# 451     16
# 619     16
# 666     17
# 708     17
# 725     16
# 758     17
# 851     17
# 978     16
# 989     16
# 1008    16
# 1009    16
# dtype: int64

# %%
df=df.drop([179, 187,429,451,619,666,708,725,758,851,978,989,1008,1009],axis=0)

# %% [markdown]
# Se realiza validación de eliminación de las filas

# %%
a = df.isnull().sum(axis=1)
print (a[a>15])
# Out:
# Series([], dtype: int64)

# %% [markdown]
# Se confirma el tamaño del Dataframe al eliminar registros duplicados y datos nulos

# %%
print(df.shape)
# Out:
# (996, 18)

# %% [markdown]
# ### **Validación de la columna edad**

# %%
df['fecha_nacimiento'] = pd.to_datetime(df['fecha_nacimiento'])

# %%
type(df['fecha_nacimiento'] )
# Out:
# pandas.core.series.Series

# %%
df['fecha_nacimiento'] = pd.to_datetime(df['fecha_nacimiento'], format = "%p-%I-%d-%m-%Y")
df['fecha_nacimiento']
# Out:
# 0      1962-11-27
# 1      2003-02-05
# 2      1977-07-30
# 3      2004-04-26
# 4      2006-04-29
#           ...
# 1003   2005-08-03
# 1004   2003-01-06
# 1005   2006-08-28
# 1006   2009-05-02
# 1007   2008-10-23
# Name: fecha_nacimiento, Length: 996, dtype: datetime64[ns]

# %%
now = datetime.now()
print(now)
# Out:
# 2022-11-19 18:13:57.832929

# %%
delta_col = timedelta(hours = 5)
now = now - delta_col
now = pd.to_datetime(now, format = "%p-%I-%d-%m-%Y")
print(now)
# Out:
# 2022-11-19 13:13:57.832929

# %%
df['Val_edad'] = now.year - df['fecha_nacimiento'].dt.year
df['Val_edad']
# Out:
# 0       60
# 1       19
# 2       45
# 3       18
# 4       16
#         ..
# 1003    17
# 1004    19
# 1005    16
# 1006    13
# 1007    14
# Name: Val_edad, Length: 996, dtype: int64

# %% [markdown]
# Se elimina la columna edad y se deja la nueva columna con el dato real

# %%
df.drop(['edad'], axis = 'columns', inplace=True)
df
# Out:
#      nombre_departamento             nombre_municipio  nombre_lugar_poblado  \
# 0             SAN MARCOS                    SAN PABLO        BARRANCA HONDA
# 1             SAN MARCOS                 COMITANCILLO              CHAMAQUE
# 2             SAN MARCOS                  SAN LORENZO  SANTA ROSA (CASERIO)
# 3             SAN MARCOS                 COMITANCILLO              CHAMAQUE
# 4             SAN MARCOS                    SAN PABLO             LA CUMBRE
# ...                  ...                          ...                   ...
# 1003          SAN MARCOS                 COMITANCILLO            CHICAJALAJ
# 1004       HUEHUETENANGO                HUEHUETENANGO           EL CARRIZAL
# 1005       HUEHUETENANGO              SAN JUAN ATITÁN              IXQUILAM
# 1006              SOLOLA           SAN JUAN LA LAGUNA             PASAJQUIM
# 1007       HUEHUETENANGO  SAN SEBASTIÁN HUEHUETENANGO                 SUJAL
#
#       cod_familia fecha_nacimiento    sexo  nucleo   estado_conyugal  \
# 0     609497670.0       1962-11-27   Mujer     1.0            Casado
# 1       8600484.0       2003-02-05   Mujer     1.0        Soltero(a)
# 2      13648135.0       1977-07-30   Mujer     1.0            Casado
# 3       8600465.0       2004-04-26   Mujer     1.0  Menos de 12 años
# 4     609499178.0       2006-04-29  Hombre     1.0  Menos de 12 años
# ...           ...              ...     ...     ...               ...
# 1003    8597929.0       2005-08-03   Mujer     1.0        Soltero(a)
# 1004  650503810.0       2003-01-06  Hombre     1.0        Soltero(a)
# 1005  657997897.0       2006-08-28  Hombre     1.0  Menos de 12 años
# 1006  358497825.0       2009-05-02  Hombre     1.0  Menos de 12 años
# 1007    9748739.0       2008-10-23   Mujer     1.0  Menos de 12 años
#
#      discapacidad_permanente sabe_leer_escribir asistencia_centro_educativo  \
# 0                        NaN                 No                          No
# 1                        NaN                 Sí                          Sí
# 2                        NaN                 Sí                          No
# 3                        NaN                 Sí                          Sí
# 4                        NaN                 Sí                          Sí
# ...                      ...                ...                         ...
# 1003                     NaN                 Sí                          Sí
# 1004                     NaN                 Sí                          Sí
# 1005                     NaN                 Sí                          Sí
# 1006                     NaN                 Sí                          Sí
# 1007                     NaN                 Sí                          Sí
#
#      razon_dejo_asistir    nivel_inscrito    nivel_aprobado  \
# 0        No le interesa           Ninguno           Ninguno
# 1                   NaN    Sexto Primaria   Quinto Primaria
# 2       Falta de dinero           Ninguno  Primero Primaria
# 3                   NaN   Cuarto Primaria  Tercero Primaria
# 4                   NaN   Quinto Primaria   Cuarto Primaria
# ...                 ...               ...               ...
# 1003                NaN   Cuarto Primaria  Tercero Primaria
# 1004                NaN   Cuarto Primaria  Tercero Primaria
# 1005                NaN  Segundo Primaria  Primero Primaria
# 1006                NaN  Primero Primaria       Preprimaria
# 1007                NaN  Segundo Primaria  Primero Primaria
#
#                      categoria_ocupacional grupo_etnico es_jefe_familia  \
# 0     Trabajador(a) cuenta propia agrícola  No indigena              Sí
# 1                                      NaN          Mam              No
# 2                               No Trabaja          Mam              No
# 3                                      NaN          Mam              No
# 4                                      NaN  No indigena              No
# ...                                    ...          ...             ...
# 1003                                   NaN          Mam              No
# 1004                                   NaN  No indigena              No
# 1005                                   NaN          Mam              No
# 1006                                   NaN        Kiche              No
# 1007                                   NaN          Mam              No
#
#       Val_edad
# 0           60
# 1           19
# 2           45
# 3           18
# 4           16
# ...        ...
# 1003        17
# 1004        19
# 1005        16
# 1006        13
# 1007        14
#
# [996 rows x 18 columns]

# %%
df.rename(columns={'Val_edad':'edad'},inplace=True)
df.columns
# Out:
# Index(['nombre_departamento', 'nombre_municipio', 'nombre_lugar_poblado',
#        'cod_familia', 'fecha_nacimiento', 'sexo', 'nucleo', 'estado_conyugal',
#        'discapacidad_permanente', 'sabe_leer_escribir',
#        'asistencia_centro_educativo', 'razon_dejo_asistir', 'nivel_inscrito',
#        'nivel_aprobado', 'categoria_ocupacional', 'grupo_etnico',
#        'es_jefe_familia', 'edad'],
#       dtype='object')

# %% [markdown]
# ### **Validación de la columna estado conyugal**

# %%
df.estado_conyugal.unique()
# Out:
# array(['Casado', 'Soltero(a)', 'Menos de 12 años', 'Unido',
#        'Separado(a) de unión', 'Separado(a) de matrimonio', 'Viudo(a)'],
#       dtype=object)

# %% [markdown]
# Se procede a realiza validación del estado conyugal de acuerdo a la columna de la edad,evidenciando inconsistencia personas mayores de 12 años con el estado conyugal "Menos de 12 años"

# %%
df1 = df[(df['estado_conyugal']=='Menos de 12 años') & (df['edad']>12)]
df1
# Out:
#      nombre_departamento             nombre_municipio nombre_lugar_poblado  \
# 3             SAN MARCOS                 COMITANCILLO             CHAMAQUE
# 4             SAN MARCOS                    SAN PABLO            LA CUMBRE
# 8             SAN MARCOS                    TAJUMULCO           TUIQUINQUE
# 10            SAN MARCOS                      TEJUTLA    LAS MANZANILLAS I
# 12                SOLOLA                       SOLOLÁ        SAN FRANCISCO
# ...                  ...                          ...                  ...
# 999           SAN MARCOS                   SAN MARCOS        LA FEDERACION
# 1000          SAN MARCOS           CONCEPCIÓN TUTUAPA              NINCHIN
# 1005       HUEHUETENANGO              SAN JUAN ATITÁN             IXQUILAM
# 1006              SOLOLA           SAN JUAN LA LAGUNA            PASAJQUIM
# 1007       HUEHUETENANGO  SAN SEBASTIÁN HUEHUETENANGO                SUJAL
#
#       cod_familia fecha_nacimiento    sexo  nucleo   estado_conyugal  \
# 3       8600465.0       2004-04-26   Mujer     1.0  Menos de 12 años
# 4     609499178.0       2006-04-29  Hombre     1.0  Menos de 12 años
# 8       8499990.0       2006-08-22  Hombre     1.0  Menos de 12 años
# 10    604998325.0       2008-05-04   Mujer     1.0  Menos de 12 años
# 12     12699344.0       2009-06-19   Mujer     1.0  Menos de 12 años
# ...           ...              ...     ...     ...               ...
# 999   600499208.0       2008-04-28  Hombre     1.0  Menos de 12 años
# 1000  602998177.0       2005-01-07   Mujer     1.0  Menos de 12 años
# 1005  657997897.0       2006-08-28  Hombre     1.0  Menos de 12 años
# 1006  358497825.0       2009-05-02  Hombre     1.0  Menos de 12 años
# 1007    9748739.0       2008-10-23   Mujer     1.0  Menos de 12 años
#
#      discapacidad_permanente sabe_leer_escribir asistencia_centro_educativo  \
# 3                        NaN                 Sí                          Sí
# 4                        NaN                 Sí                          Sí
# 8                        NaN                 Sí                          Sí
# 10                       NaN                 Sí                          Sí
# 12                       NaN                 No                          Sí
# ...                      ...                ...                         ...
# 999                      NaN                 Sí                          Sí
# 1000                     NaN                 Sí                          Sí
# 1005                     NaN                 Sí                          Sí
# 1006                     NaN                 Sí                          Sí
# 1007                     NaN                 Sí                          Sí
#
#      razon_dejo_asistir    nivel_inscrito    nivel_aprobado  \
# 3                   NaN   Cuarto Primaria  Tercero Primaria
# 4                   NaN   Quinto Primaria   Cuarto Primaria
# 8                   NaN   Cuarto Primaria  Tercero Primaria
# 10                  NaN  Tercero Primaria  Segundo Primaria
# 12                  NaN  Primero Primaria       Preprimaria
# ...                 ...               ...               ...
# 999                 NaN   Cuarto Primaria  Tercero Primaria
# 1000                NaN   Quinto Primaria   Cuarto Primaria
# 1005                NaN  Segundo Primaria  Primero Primaria
# 1006                NaN  Primero Primaria       Preprimaria
# 1007                NaN  Segundo Primaria  Primero Primaria
#
#      categoria_ocupacional grupo_etnico es_jefe_familia  edad
# 3                      NaN          Mam              No    18
# 4                      NaN  No indigena              No    16
# 8                      NaN          Mam              No    16
# 10                     NaN  No indigena              No    14
# 12                     NaN    Kaqchikel              No    13
# ...                    ...          ...             ...   ...
# 999                    NaN  No indigena              No    14
# 1000                   NaN          Mam              No    17
# 1005                   NaN          Mam              No    16
# 1006                   NaN        Kiche              No    13
# 1007                   NaN          Mam              No    14
#
# [308 rows x 18 columns]

# %%
df['estado_conyugal'].loc[(df["estado_conyugal"] == 'Menos de 12 años') & (df['edad']>12)] = 'Soltero(a)'
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
df1 = df[(df['estado_conyugal']=='Menos de 12 años') & (df['edad']>12)]
df1
# Out:
# Empty DataFrame
# Columns: [nombre_departamento, nombre_municipio, nombre_lugar_poblado, cod_familia, fecha_nacimiento, sexo, nucleo, estado_conyugal, discapacidad_permanente, sabe_leer_escribir, asistencia_centro_educativo, razon_dejo_asistir, nivel_inscrito, nivel_aprobado, categoria_ocupacional, grupo_etnico, es_jefe_familia, edad]
# Index: []

# %%
df['estado_conyugal'].loc[(df["estado_conyugal"] == 'Menos de 12 años')] = 'Menor de edad'

# %% [markdown]
# ### **Se realiza validación del grupo etnico que coincida con los grupo etnicos establecidos en la conceptualización**
#
#
#  Achi, Akateco, Awakateco, Chalchiteco, Ch’orti’, Chuj, Itza’, Ixil, Jacalteco, Kaqchikel, K’iche’, Mam, Mopan, Poqomam, Poqomchi’, Q’anjob’al, Q’eqchi’, Sakapulteco, Sipakapense, Tektiteko, Tz’utujil y Uspanteko.

# %%
df1= df.groupby(['grupo_etnico'])['edad'].count()
df1
# Out:
# grupo_etnico
# Akateko          1
# Chuj             9
# Jakateko         3
# Kaqchikel      100
# Kiche          324
# Mam            253
# No indigena    243
# Qanjobal         3
# Tzutujil        60
# Name: edad, dtype: int64

# %%
df['grupo_etnico'].loc[(df['grupo_etnico'] == 'Jakateko')] = 'Jacalteco'

# %%
df1= df.groupby(['grupo_etnico'])['edad'].count()
df1
# Out:
# grupo_etnico
# Akateko          1
# Chuj             9
# Jacalteco        3
# Kaqchikel      100
# Kiche          324
# Mam            253
# No indigena    243
# Qanjobal         3
# Tzutujil        60
# Name: edad, dtype: int64

# %%
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# Eliminación de tildes

# %%
import unicodedata

def strip_accents(s):
  if (type(s) == str):
    return ''.join(c for c in unicodedata.normalize('NFD', s) if unicodedata.category(c) != 'Mn')
  return s




for column in df.keys():
  df[column] = df[column].map(strip_accents)

df
# Out:
#     nombre_departamento             nombre_municipio  nombre_lugar_poblado  \
# 0            SAN MARCOS                    SAN PABLO        BARRANCA HONDA
# 1            SAN MARCOS                 COMITANCILLO              CHAMAQUE
# 2            SAN MARCOS                  SAN LORENZO  SANTA ROSA (CASERIO)
# 3            SAN MARCOS                 COMITANCILLO              CHAMAQUE
# 4            SAN MARCOS                    SAN PABLO             LA CUMBRE
# ..                  ...                          ...                   ...
# 991          SAN MARCOS                 COMITANCILLO            CHICAJALAJ
# 992       HUEHUETENANGO                HUEHUETENANGO           EL CARRIZAL
# 993       HUEHUETENANGO              SAN JUAN ATITAN              IXQUILAM
# 994              SOLOLA           SAN JUAN LA LAGUNA             PASAJQUIM
# 995       HUEHUETENANGO  SAN SEBASTIAN HUEHUETENANGO                 SUJAL
#
#      cod_familia fecha_nacimiento    sexo  nucleo estado_conyugal  \
# 0    609497670.0       1962-11-27   Mujer     1.0          Casado
# 1      8600484.0       2003-02-05   Mujer     1.0      Soltero(a)
# 2     13648135.0       1977-07-30   Mujer     1.0          Casado
# 3      8600465.0       2004-04-26   Mujer     1.0      Soltero(a)
# 4    609499178.0       2006-04-29  Hombre     1.0      Soltero(a)
# ..           ...              ...     ...     ...             ...
# 991    8597929.0       2005-08-03   Mujer     1.0      Soltero(a)
# 992  650503810.0       2003-01-06  Hombre     1.0      Soltero(a)
# 993  657997897.0       2006-08-28  Hombre     1.0      Soltero(a)
# 994  358497825.0       2009-05-02  Hombre     1.0      Soltero(a)
# 995    9748739.0       2008-10-23   Mujer     1.0      Soltero(a)
#
#     discapacidad_permanente sabe_leer_escribir asistencia_centro_educativo  \
# 0                       NaN                 No                          No
# 1                       NaN                 Si                          Si
# 2                       NaN                 Si                          No
# 3                       NaN                 Si                          Si
# 4                       NaN                 Si                          Si
# ..                      ...                ...                         ...
# 991                     NaN                 Si                          Si
# 992                     NaN                 Si                          Si
# 993                     NaN                 Si                          Si
# 994                     NaN                 Si                          Si
# 995                     NaN                 Si                          Si
#
#     razon_dejo_asistir    nivel_inscrito    nivel_aprobado  \
# 0       No le interesa           Ninguno           Ninguno
# 1                  NaN    Sexto Primaria   Quinto Primaria
# 2      Falta de dinero           Ninguno  Primero Primaria
# 3                  NaN   Cuarto Primaria  Tercero Primaria
# 4                  NaN   Quinto Primaria   Cuarto Primaria
# ..                 ...               ...               ...
# 991                NaN   Cuarto Primaria  Tercero Primaria
# 992                NaN   Cuarto Primaria  Tercero Primaria
# 993                NaN  Segundo Primaria  Primero Primaria
# 994                NaN  Primero Primaria       Preprimaria
# 995                NaN  Segundo Primaria  Primero Primaria
#
#                     categoria_ocupacional grupo_etnico es_jefe_familia  edad
# 0    Trabajador(a) cuenta propia agricola  No indigena              Si    60
# 1                                     NaN          Mam              No    19
# 2                              No Trabaja          Mam              No    45
# 3                                     NaN          Mam              No    18
# 4                                     NaN  No indigena              No    16
# ..                                    ...          ...             ...   ...
# 991                                   NaN          Mam              No    17
# 992                                   NaN  No indigena              No    19
# 993                                   NaN          Mam              No    16
# 994                                   NaN        Kiche              No    13
# 995                                   NaN          Mam              No    14
#
# [996 rows x 18 columns]

# %% [markdown]
# *Para uso en modelos*: Convertir las variables en categorías para facilitar su inclusión

# %%
df['nombre_departamento'] = df.nombre_departamento.astype('category')
df['nombre_municipio'] = df.nombre_municipio.astype('category')
df['nombre_lugar_poblado'] = df.nombre_lugar_poblado.astype('category')
df['sexo'] = df.sexo.astype('category')
df['estado_conyugal'] = df.estado_conyugal.astype('category')
df['discapacidad_permanente'] = df.discapacidad_permanente.astype('category')
df['sabe_leer_escribir'] = df.sabe_leer_escribir.astype('category')
df['asistencia_centro_educativo'] = df.asistencia_centro_educativo.astype('category')
df['razon_dejo_asistir'] = df.razon_dejo_asistir.astype('category')
df['nivel_inscrito'] = df.nivel_inscrito.astype('category')
df['nivel_aprobado'] = df.nivel_aprobado.astype('category')
df['categoria_ocupacional'] = df.categoria_ocupacional.astype('category')
df['grupo_etnico'] = df.grupo_etnico.astype('category')
df['es_jefe_familia'] = df.es_jefe_familia.astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 996 entries, 0 to 995
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   nombre_departamento          996 non-null    category
#  1   nombre_municipio             996 non-null    category
#  2   nombre_lugar_poblado         996 non-null    category
#  3   cod_familia                  996 non-null    float64
#  4   fecha_nacimiento             996 non-null    datetime64[ns]
#  5   sexo                         996 non-null    category
#  6   nucleo                       996 non-null    float64
#  7   estado_conyugal              996 non-null    category
#  8   discapacidad_permanente      2 non-null      category
#  9   sabe_leer_escribir           831 non-null    category
#  10  asistencia_centro_educativo  831 non-null    category
#  11  razon_dejo_asistir           341 non-null    category
#  12  nivel_inscrito               996 non-null    category
#  13  nivel_aprobado               996 non-null    category
#  14  categoria_ocupacional        263 non-null    category
#  15  grupo_etnico                 996 non-null    category
#  16  es_jefe_familia              996 non-null    category
#  17  edad                         996 non-null    int64
# dtypes: category(14), datetime64[ns](1), float64(2), int64(1)
# memory usage: 55.2 KB

# %% [markdown]
# Resultado final de transformación del set

# %%
celdas1=df.shape[0]*df.shape[1]
celdas1
# Out:
# 17928

# %%
diferencia= celdas0-celdas1
diferencia
# Out:
# 211459

# %%
cociente_borrado= diferencia/celdas0
cociente_borrado
# Out:
# 0.9218438708383648

# %% [markdown]
# Descargar dataset

# %%
df.to_csv('Encuesta_Pobreza.csv')
files.download('Encuesta_Pobreza.csv')
